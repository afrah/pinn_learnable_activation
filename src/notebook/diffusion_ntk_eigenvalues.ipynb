# %% [markdown]
# # Spectral Bias Analysis using Trace Jacobian of PINN Loss Terms for Convection-diffusion

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import torch
import gc
import numpy as np
from matplotlib import pyplot as plt
import os

# %% [markdown]
# Import local packages

# %%
from src.utils.logger import Logging
from src.utils.color import model_color
from src.utils.plot_eigenvalues import plot_ntk_eigenvalues

# %% [markdown]
# Set various constant variables: model path, name, etc. We choose the best performing models from each architecture.

# %%
TEST_CHECKPOINT_PATH = os.path.join("result/diffusion")
logger = Logging(TEST_CHECKPOINT_PATH)
result_dir = logger.get_output_dir()

# %%
# # tanh

# python -m src.trainer.main_trainer --total_epochs 60000  --save_every 1000 --print_every 1000 --batch_size 128 --log_path ./checkpoints --solver tanh --problem diffusion  --weights "[10.0, 10.0, 1.0]" --network "[3, 50, 50, 50, 1]"

# # param_tanh

# python -m src.trainer.main_trainer --total_epochs 60000  --save_every 1000 --print_every 1000 --batch_size 128 --log_path ./checkpoints --solver param_tanh --problem diffusion  --weights "[10.0, 10.0, 1.0]" --network "[3, 300, 300, 300, 1]"

# # fourier

# python -m src.trainer.main_trainer --total_epochs 60000  --save_every 1000 --print_every 1000 --batch_size 128 --log_path ./checkpoints --solver fourier --problem diffusion  --weights "[10.0, 10.0, 1.0]" --network "[3, 50, 50, 50, 1]"

# # grbf

# python -m src.trainer.main_trainer --total_epochs 60000  --save_every 1000 --print_every 1000 --batch_size 128 --log_path ./checkpoints --solver grbf --problem diffusion  --weights "[10.0, 10.0, 1.0]" --network "[3, 50, 50, 50, 1]"

# # chebyshev

# python -m src.trainer.main_trainer --total_epochs 60000  --save_every 1000 --print_every 1000 --batch_size 128 --log_path ./checkpoints --solver chebyshev --problem diffusion  --weights "[10.0, 10.0, 1.0]" --network "[3, 50, 50, 50, 1]"

# # jacobi

# python -m src.trainer.main_trainer --total_epochs 60000  --save_every 1000 --print_every 1000 --batch_size 128 --log_path ./checkpoints --solver jacobi --problem diffusion  --weights "[10.0, 10.0, 1.0]" --network "[3, 50, 50, 50, 1]"

# # param_tanh

# python -m src.trainer.main_trainer --total_epochs 60000  --save_every 1000 --print_every 1000 --batch_size 128 --log_path ./checkpoints --solver param_tanh --problem diffusion  --weights "[10.0, 10.0, 1.0]" --network "[3, 50, 50, 50, 1]"

# # bspline

# python -m src.trainer.main_trainer --total_epochs 60000  --save_every 1000 --print_every 1000 --batch_size 128 --log_path ./checkpoints --solver bspline --problem diffusion  --weights "[10.0, 10.0, 1.0]" --network "[3, 50, 50, 50, 1]"

# %%
TANH_NORM_DIST = "./checkpoints/2025-05-30_12-44-21-546589/model.pth"
TANH_PARAM_DIST = "./checkpoints/2025-05-30_12-45-02-459385/model.pth"
BSPLINE_DIST = "./checkpoints/2025-05-30_12-49-14-710100/model.pth"
GRBF_DIST = "./checkpoints/2025-05-30_12-47-21-224710/model.pth"
FOURIER_DIST = "./checkpoints/2025-05-30_12-46-10-289074/model.pth"
CHEBTSHEV_DIST = "./checkpoints/2025-05-30_12-48-12-139287/model.pth"
JACOBI_DIST = "./checkpoints/2025-05-30_12-50-28-886447/model.pth"


MODEL_PATH_LIST = {
    "tanh": TANH_NORM_DIST,
    "param_tanh": TANH_PARAM_DIST,
    "grbf": GRBF_DIST,
    "bspline": BSPLINE_DIST,
    "chebyshev": CHEBTSHEV_DIST,
    "jacobi": JACOBI_DIST,
    "fourier": FOURIER_DIST,
}

# %% [markdown]
# ## Load the saved models

# %%
trace_jacobian_bc_log_dic = {}
trace_jacobian_res_log_dic = {}
trace_jacobian_ic_log_dic = {}

for model_name, model_path in MODEL_PATH_LIST.items():
    logger.print(f"MODEL_PATH {model_path}")
    state = torch.load(
        model_path,
    )
    config = state.get("config", {})
    solver = config.get("solver")
    trace_jacobian_bc_log = state.get("trace_jacobian_bc_log")
    trace_jacobian_ic_log = state.get("trace_jacobian_ic_log")
    trace_jacobian_res_log = state.get("trace_jacobian_res_log")

    model_activation_name = config.get("activation")
    model_architecture = config.get("network")
    loss_dict = state.get("loss_history")

    logger.print(f"activation:  , {model_activation_name}")
    logger.print(f"problem: {config.get('problem')}")
    logger.print(f"solver:  , {solver}")
    logger.print(f"network:  , {config.get('network')}")
    logger.print(f"term loss weights :  , {config.get('weights')}")

    # logger.print(
    #     f"Model {model_name} with iterations: {len(loss_dict[next(iter(loss_dict))])}"
    # )

    trace_jacobian_bc_log_dic[model_name] = trace_jacobian_bc_log
    trace_jacobian_res_log_dic[model_name] = trace_jacobian_res_log
    trace_jacobian_ic_log_dic[model_name] = trace_jacobian_ic_log

    logger.print("******************************\n")
    gc.collect()
    torch.cuda.empty_cache()

logger.print("file directory:", logger.get_output_dir())
# Out:
# INFO:src.utils.logger:MODEL_PATH ./checkpoints/2025-05-30_12-44-21-546589/model.pth
# INFO:src.utils.logger:activation:  , None
# INFO:src.utils.logger:problem: diffusion
# INFO:src.utils.logger:solver:  , tanh
# INFO:src.utils.logger:network:  , [3, 50, 50, 50, 1]
# INFO:src.utils.logger:term loss weights :  , [10.0, 10.0, 1.0]
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:MODEL_PATH ./checkpoints/2025-05-30_12-45-02-459385/model.pth
# INFO:src.utils.logger:activation:  , None
# INFO:src.utils.logger:problem: diffusion
# INFO:src.utils.logger:solver:  , param_tanh
# INFO:src.utils.logger:network:  , [3, 300, 300, 300, 1]
# INFO:src.utils.logger:term loss weights :  , [10.0, 10.0, 1.0]
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:MODEL_PATH ./checkpoints/2025-05-30_12-47-21-224710/model.pth
# INFO:src.utils.logger:activation:  , None
# INFO:src.utils.logger:problem: diffusion
# ...

# %%
fontsize = 11
min_length = min(len(trace_jacobian_bc_log_dic[k]) for k in trace_jacobian_bc_log_dic)
time_iterations = [0, min_length // 2, min_length - 1]

dict_list = [
    trace_jacobian_bc_log_dic,
    trace_jacobian_ic_log_dic,
    trace_jacobian_res_log_dic,
]

rows = len(time_iterations)
cols = len(dict_list)

fig, ax = plt.subplots(rows, cols)
fig.set_size_inches([10, 6])

lines = []
labels = []

for row, time_iteration in enumerate(time_iterations):
    for col, dict_ in enumerate(dict_list):
        data_list = [
            {
                "data": dict_["bspline"][time_iteration],
                "color": model_color["bspline"],
                "name": "B-spline(A1)",
                "alpha": 1.0,
            },
            {
                "data": dict_["tanh"][time_iteration],
                "color": model_color["tanh"],
                "name": "Tanh(A1)",
                "alpha": 1.0,
            },
            {
                "data": dict_["grbf"][time_iteration],
                "color": model_color["grbf"],
                "name": "GRBF(A1)",
                "alpha": 1.0,
            },
            {
                "data": dict_["fourier"][time_iteration],
                "color": model_color["fourier"],
                "name": "Fourier(A1)",
                "alpha": 1.0,
            },
            {
                "data": dict_["param_tanh"][time_iteration],
                "color": model_color["param_tanh"],
                "name": "parametric-Tanh(A2)",
                "alpha": 1.0,
            },
            {
                "data": dict_["chebyshev"][time_iteration],
                "color": model_color["chebyshev"],
                "name": "Chebyshev(A1)",
                "alpha": 1.0,
            },
            {
                "data": dict_["jacobi"][time_iteration],
                "color": model_color["jacobi"],
                "name": "Jacobi(A1)",
                "alpha": 1.0,
            },
        ]

        plot_ntk_eigenvalues(
            ax[row, col], data_list, row, col, smoothed_data=False, fontsize=fontsize
        )

legend_labels = []
legend_colors = []

for line in ax[-1, -1].get_lines():
    legend_labels.append(line.get_label())
    legend_colors.append(line.get_color())

save_path = os.path.join(logger.get_output_dir(), "ntk_eigenvalues_diffusion.png")

legend = fig.legend(
    legend_labels,
    loc="upper center",
    bbox_to_anchor=(0.5, 1.05),
    ncol=7,
    prop={"size": fontsize},
    handlelength=0,
)

for text, color in zip(legend.get_texts(), legend_colors):
    text.set_color(color)

legend.get_frame().set_linewidth(0)
legend.get_frame().set_facecolor("none")

plt.tight_layout()
plt.savefig(save_path, bbox_extra_artists=(legend,), bbox_inches="tight")
