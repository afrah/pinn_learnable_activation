# %% [markdown]
# # Training Cavity Model

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
import torch
import numpy as np
import gc

import h5py
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# Import local packages

# %%
from src.utils.logger import Logging
from src.utils.utils import lp_error
from src.utils.color import model_color
from src.utils.plot_spectral import plot_spectral
from src.utils.plot_loss import plot_loss_history

# %% [markdown]
# Set various constant variables: model path, name, etc.

# %%
TEST_CHECKPOINT_PATH = "./checkpoint"
logger = Logging(TEST_CHECKPOINT_PATH)
model_dirname = logger.get_output_dir()

local_rank = 0
world_size = 1

# %% [markdown]
# ## Load the Model and Test

# %%
TEST_DATA_PKL = "./data/cavity.mat"
data = h5py.File(TEST_DATA_PKL, "r")  # load dataset from matlab

domain = pd.DataFrame(data["cavity_internal"]).T.to_numpy()

#  t = tf.reshape(tstep,N_data)[:,0].T
time_ = domain[:, 0:1]
xfa = domain[:, 1:2]
yfa = domain[:, 2:3]
ufa = domain[:, 3:4]
vfa = domain[:, 4:5]
pfa = domain[:, 5:6]

# %%
config = {
    "problem": "cavity",
    "dataset_path": "./data/cavity.mat",
    "batch_size": 128,
    "total_epochs": 60000,
    "activation": "tanh",
    "network": [3, 50, 50, 50, 3],
    "weights": [2.0, 2.0, 2.0, 2.0, 2.0, 0.1],
    "log_path": TEST_CHECKPOINT_PATH,
    "loss_list": ["lleft", "lright", "lbottom", "lup", "linitial", "lphy"],
    "solver": "tanh",
    "print_every": 100,
    "save_every": 100,
}

# %%
from src.trainer import cavity_trainer
from src.nn.tanh_parameterized import PINNKAN
from src.data.cavity_dataset import CavityDatasetFromFile

model = PINNKAN(config.get("network"), config.get("activation")).to("cpu")
obj = CavityDatasetFromFile(config.get("dataset_path"), 0)
train_dataloader = obj.__getitem__()

optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-6)


trainer = cavity_trainer.Trainer(
    model,
    train_dataloader,
    optimizer,
    local_rank,
    config,
)

trainer.train_mini_batch()
# Out:
# INFO:src.utils.logger:checkpoint path: self.log_path='./checkpoint/2025-05-24_10-29-34-158138'
# INFO:src.utils.logger: Epoch: 0 | Time: 0.02s | rTime: 1.799e-02h | LR: 1.000e-03 |loss: 2.390e+00 | trace_jacobian_bc: 2.311e+02 | trace_jacobian_ic: 1.389e+02 | trace_jacobian_res: 3.365e+00 | lleft: 3.908e-02 | lright: 4.866e-02 | lbottom: 1.905e-02 | lup: 1.056e+00 | linitial: 1.096e+00 | lphy: 1.316e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 3.908e-02 |  Final lright: 4.866e-02 |  Final lbottom: 1.905e-02 |  Final lup: 1.056e+00 |  Final linitial: 1.096e+00 |  Final lphy: 1.316e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 0 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# domain.shape=(10100, 6), left.shape=(1515, 6), bottom.shape=(1515, 6), up.shape=(1515, 6), right.shape=(1515, 6), initial.shape=(1500, 6), sensors.shape=(5050, 6)
# INFO:src.utils.logger: Epoch: 1 | Time: 0.02s | rTime: 3.430e-02h | LR: 1.000e-03 |loss: 5.305e-01 | trace_jacobian_bc: 7.678e+00 | trace_jacobian_ic: 6.460e+00 | trace_jacobian_res: 1.985e-02 | lleft: 7.237e-02 | lright: 5.898e-02 | lbottom: 1.570e-02 | lup: 2.583e-01 | linitial: 1.223e-01 | lphy: 2.877e-03 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 7.237e-02 |  Final lright: 5.898e-02 |  Final lbottom: 1.570e-02 |  Final lup: 2.583e-01 |  Final linitial: 1.223e-01 |  Final lphy: 2.877e-03 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 100 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 2 | Time: 0.02s | rTime: 5.121e-02h | LR: 1.000e-03 |loss: 4.848e-01 | trace_jacobian_bc: 1.148e+01 | trace_jacobian_ic: 6.126e+00 | trace_jacobian_res: 2.715e-02 | lleft: 7.225e-02 | lright: 6.172e-02 | lbottom: 1.552e-02 | lup: 2.203e-01 | linitial: 1.097e-01 | lphy: 5.333e-03 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 7.225e-02 |  Final lright: 6.172e-02 |  Final lbottom: 1.552e-02 |  Final lup: 2.203e-01 |  Final linitial: 1.097e-01 |  Final lphy: 5.333e-03 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 200 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 3 | Time: 0.02s | rTime: 6.787e-02h | LR: 1.000e-03 |loss: 2.990e-01 | trace_jacobian_bc: 2.728e+01 | trace_jacobian_ic: 2.870e+00 | trace_jacobian_res: 3.030e-01 | lleft: 5.513e-02 | lright: 3.382e-02 | lbottom: 3.140e-03 | lup: 1.342e-01 | linitial: 5.674e-02 | lphy: 1.598e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 5.513e-02 |  Final lright: 3.382e-02 |  Final lbottom: 3.140e-03 |  Final lup: 1.342e-01 |  Final linitial: 5.674e-02 |  Final lphy: 1.598e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 300 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 4 | Time: 0.02s | rTime: 8.388e-02h | LR: 1.000e-03 |loss: 2.219e-01 | trace_jacobian_bc: 2.620e+01 | trace_jacobian_ic: 2.181e+00 | trace_jacobian_res: 7.768e-01 | lleft: 2.681e-02 | lright: 2.611e-02 | lbottom: 8.837e-04 | lup: 8.456e-02 | linitial: 5.178e-02 | lphy: 3.180e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 2.681e-02 |  Final lright: 2.611e-02 |  Final lbottom: 8.837e-04 |  Final lup: 8.456e-02 |  Final linitial: 5.178e-02 |  Final lphy: 3.180e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 400 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 5 | Time: 0.02s | rTime: 1.037e-01h | LR: 1.000e-03 |loss: 1.761e-01 | trace_jacobian_bc: 1.721e+01 | trace_jacobian_ic: 1.371e+00 | trace_jacobian_res: 3.745e+00 | lleft: 2.975e-02 | lright: 1.676e-02 | lbottom: 6.151e-04 | lup: 4.155e-02 | linitial: 3.925e-02 | lphy: 4.816e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 2.975e-02 |  Final lright: 1.676e-02 |  Final lbottom: 6.151e-04 |  Final lup: 4.155e-02 |  Final linitial: 3.925e-02 |  Final lphy: 4.816e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 500 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 6 | Time: 0.02s | rTime: 1.203e-01h | LR: 1.000e-03 |loss: 2.209e-01 | trace_jacobian_bc: 1.667e+00 | trace_jacobian_ic: 9.151e-01 | trace_jacobian_res: 1.301e+01 | lleft: 2.491e-02 | lright: 2.972e-02 | lbottom: 6.241e-04 | lup: 3.386e-02 | linitial: 4.038e-02 | lphy: 9.141e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 2.491e-02 |  Final lright: 2.972e-02 |  Final lbottom: 6.241e-04 |  Final lup: 3.386e-02 |  Final linitial: 4.038e-02 |  Final lphy: 9.141e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 600 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 7 | Time: 0.02s | rTime: 1.367e-01h | LR: 1.000e-03 |loss: 1.647e-01 | trace_jacobian_bc: 4.321e+00 | trace_jacobian_ic: 7.988e-01 | trace_jacobian_res: 1.495e+01 | lleft: 2.861e-02 | lright: 2.769e-02 | lbottom: 5.263e-04 | lup: 2.426e-02 | linitial: 3.707e-02 | lphy: 4.655e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 2.861e-02 |  Final lright: 2.769e-02 |  Final lbottom: 5.263e-04 |  Final lup: 2.426e-02 |  Final linitial: 3.707e-02 |  Final lphy: 4.655e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 700 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 8 | Time: 0.02s | rTime: 1.552e-01h | LR: 1.000e-03 |loss: 1.300e-01 | trace_jacobian_bc: 9.765e+00 | trace_jacobian_ic: 6.445e-01 | trace_jacobian_res: 2.305e+01 | lleft: 6.540e-03 | lright: 2.115e-02 | lbottom: 3.741e-04 | lup: 2.906e-02 | linitial: 3.292e-02 | lphy: 4.000e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 6.540e-03 |  Final lright: 2.115e-02 |  Final lbottom: 3.741e-04 |  Final lup: 2.906e-02 |  Final linitial: 3.292e-02 |  Final lphy: 4.000e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 800 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 9 | Time: 0.02s | rTime: 1.712e-01h | LR: 1.000e-03 |loss: 1.547e-01 | trace_jacobian_bc: 3.172e+02 | trace_jacobian_ic: 8.012e-01 | trace_jacobian_res: 1.335e+01 | lleft: 1.066e-02 | lright: 1.167e-02 | lbottom: 4.039e-04 | lup: 6.321e-02 | linitial: 3.601e-02 | lphy: 3.274e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.066e-02 |  Final lright: 1.167e-02 |  Final lbottom: 4.039e-04 |  Final lup: 6.321e-02 |  Final linitial: 3.601e-02 |  Final lphy: 3.274e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 900 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 10 | Time: 0.02s | rTime: 1.891e-01h | LR: 1.000e-03 |loss: 1.388e-01 | trace_jacobian_bc: 5.113e+00 | trace_jacobian_ic: 4.559e-01 | trace_jacobian_res: 1.935e+01 | lleft: 1.782e-02 | lright: 1.184e-02 | lbottom: 2.520e-04 | lup: 2.239e-02 | linitial: 3.084e-02 | lphy: 5.562e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.782e-02 |  Final lright: 1.184e-02 |  Final lbottom: 2.520e-04 |  Final lup: 2.239e-02 |  Final linitial: 3.084e-02 |  Final lphy: 5.562e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 1000 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 11 | Time: 0.02s | rTime: 2.062e-01h | LR: 1.000e-03 |loss: 1.174e-01 | trace_jacobian_bc: 1.050e+01 | trace_jacobian_ic: 5.755e-01 | trace_jacobian_res: 1.979e+01 | lleft: 1.827e-02 | lright: 1.382e-02 | lbottom: 3.854e-04 | lup: 2.221e-02 | linitial: 2.445e-02 | lphy: 3.824e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.827e-02 |  Final lright: 1.382e-02 |  Final lbottom: 3.854e-04 |  Final lup: 2.221e-02 |  Final linitial: 2.445e-02 |  Final lphy: 3.824e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 1100 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 12 | Time: 0.02s | rTime: 2.222e-01h | LR: 1.000e-03 |loss: 1.098e-01 | trace_jacobian_bc: 1.020e+02 | trace_jacobian_ic: 1.171e+00 | trace_jacobian_res: 1.003e+01 | lleft: 1.155e-02 | lright: 9.180e-03 | lbottom: 2.534e-04 | lup: 3.025e-02 | linitial: 2.622e-02 | lphy: 3.235e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.155e-02 |  Final lright: 9.180e-03 |  Final lbottom: 2.534e-04 |  Final lup: 3.025e-02 |  Final linitial: 2.622e-02 |  Final lphy: 3.235e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 1200 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 13 | Time: 0.02s | rTime: 2.388e-01h | LR: 1.000e-03 |loss: 1.147e-01 | trace_jacobian_bc: 9.334e+00 | trace_jacobian_ic: 2.595e-01 | trace_jacobian_res: 3.530e+01 | lleft: 1.320e-02 | lright: 1.658e-02 | lbottom: 3.796e-04 | lup: 2.131e-02 | linitial: 2.381e-02 | lphy: 3.938e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.320e-02 |  Final lright: 1.658e-02 |  Final lbottom: 3.796e-04 |  Final lup: 2.131e-02 |  Final linitial: 2.381e-02 |  Final lphy: 3.938e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 1300 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 14 | Time: 0.02s | rTime: 2.552e-01h | LR: 1.000e-03 |loss: 1.521e-01 | trace_jacobian_bc: 7.793e+01 | trace_jacobian_ic: 1.101e+00 | trace_jacobian_res: 3.078e+01 | lleft: 1.074e-02 | lright: 9.047e-03 | lbottom: 2.315e-04 | lup: 4.122e-02 | linitial: 2.898e-02 | lphy: 6.184e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.074e-02 |  Final lright: 9.047e-03 |  Final lbottom: 2.315e-04 |  Final lup: 4.122e-02 |  Final linitial: 2.898e-02 |  Final lphy: 6.184e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 1400 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 15 | Time: 0.02s | rTime: 2.716e-01h | LR: 1.000e-03 |loss: 1.164e-01 | trace_jacobian_bc: 2.739e+01 | trace_jacobian_ic: 5.011e-01 | trace_jacobian_res: 1.570e+01 | lleft: 1.408e-02 | lright: 1.416e-02 | lbottom: 3.060e-04 | lup: 1.633e-02 | linitial: 1.706e-02 | lphy: 5.444e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.408e-02 |  Final lright: 1.416e-02 |  Final lbottom: 3.060e-04 |  Final lup: 1.633e-02 |  Final linitial: 1.706e-02 |  Final lphy: 5.444e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 1500 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 16 | Time: 0.02s | rTime: 2.878e-01h | LR: 1.000e-03 |loss: 1.781e-01 | trace_jacobian_bc: 7.862e+01 | trace_jacobian_ic: 4.460e-01 | trace_jacobian_res: 6.259e+01 | lleft: 6.803e-03 | lright: 2.909e-02 | lbottom: 1.654e-04 | lup: 1.739e-02 | linitial: 2.575e-02 | lphy: 9.892e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 6.803e-03 |  Final lright: 2.909e-02 |  Final lbottom: 1.654e-04 |  Final lup: 1.739e-02 |  Final linitial: 2.575e-02 |  Final lphy: 9.892e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 1600 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 17 | Time: 0.02s | rTime: 3.069e-01h | LR: 1.000e-03 |loss: 1.298e-01 | trace_jacobian_bc: 7.329e+01 | trace_jacobian_ic: 8.958e-01 | trace_jacobian_res: 2.438e+01 | lleft: 1.524e-02 | lright: 1.577e-02 | lbottom: 2.706e-04 | lup: 2.235e-02 | linitial: 2.762e-02 | lphy: 4.850e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.524e-02 |  Final lright: 1.577e-02 |  Final lbottom: 2.706e-04 |  Final lup: 2.235e-02 |  Final linitial: 2.762e-02 |  Final lphy: 4.850e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 1700 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 18 | Time: 0.02s | rTime: 3.231e-01h | LR: 1.000e-03 |loss: 1.044e-01 | trace_jacobian_bc: 4.644e+01 | trace_jacobian_ic: 4.534e-01 | trace_jacobian_res: 1.638e+01 | lleft: 9.352e-03 | lright: 9.860e-03 | lbottom: 3.862e-04 | lup: 2.161e-02 | linitial: 2.323e-02 | lphy: 3.993e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 9.352e-03 |  Final lright: 9.860e-03 |  Final lbottom: 3.862e-04 |  Final lup: 2.161e-02 |  Final linitial: 2.323e-02 |  Final lphy: 3.993e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 1800 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 19 | Time: 0.02s | rTime: 3.434e-01h | LR: 1.000e-03 |loss: 1.195e-01 | trace_jacobian_bc: 8.353e+01 | trace_jacobian_ic: 4.864e-01 | trace_jacobian_res: 2.686e+01 | lleft: 9.318e-03 | lright: 2.446e-02 | lbottom: 1.539e-04 | lup: 1.815e-02 | linitial: 2.153e-02 | lphy: 4.587e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 9.318e-03 |  Final lright: 2.446e-02 |  Final lbottom: 1.539e-04 |  Final lup: 1.815e-02 |  Final linitial: 2.153e-02 |  Final lphy: 4.587e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 1900 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 20 | Time: 0.02s | rTime: 3.588e-01h | LR: 1.000e-03 |loss: 1.352e-01 | trace_jacobian_bc: 1.341e+00 | trace_jacobian_ic: 1.218e+00 | trace_jacobian_res: 1.051e+01 | lleft: 9.245e-03 | lright: 6.882e-03 | lbottom: 1.144e-04 | lup: 2.074e-02 | linitial: 2.843e-02 | lphy: 6.982e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 9.245e-03 |  Final lright: 6.882e-03 |  Final lbottom: 1.144e-04 |  Final lup: 2.074e-02 |  Final linitial: 2.843e-02 |  Final lphy: 6.982e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 2000 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 21 | Time: 0.02s | rTime: 3.836e-01h | LR: 1.000e-03 |loss: 1.079e-01 | trace_jacobian_bc: 5.747e+00 | trace_jacobian_ic: 8.798e-01 | trace_jacobian_res: 4.282e+01 | lleft: 6.603e-03 | lright: 3.803e-03 | lbottom: 2.906e-04 | lup: 1.415e-02 | linitial: 2.016e-02 | lphy: 6.285e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 6.603e-03 |  Final lright: 3.803e-03 |  Final lbottom: 2.906e-04 |  Final lup: 1.415e-02 |  Final linitial: 2.016e-02 |  Final lphy: 6.285e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 2100 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 22 | Time: 0.02s | rTime: 3.990e-01h | LR: 1.000e-03 |loss: 1.373e-01 | trace_jacobian_bc: 5.534e+00 | trace_jacobian_ic: 1.204e+00 | trace_jacobian_res: 5.080e+01 | lleft: 8.244e-03 | lright: 1.741e-02 | lbottom: 2.009e-04 | lup: 2.224e-02 | linitial: 2.654e-02 | lphy: 6.267e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 8.244e-03 |  Final lright: 1.741e-02 |  Final lbottom: 2.009e-04 |  Final lup: 2.224e-02 |  Final linitial: 2.654e-02 |  Final lphy: 6.267e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 2200 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 23 | Time: 0.02s | rTime: 4.170e-01h | LR: 1.000e-03 |loss: 1.813e-01 | trace_jacobian_bc: 6.383e+01 | trace_jacobian_ic: 3.844e-01 | trace_jacobian_res: 6.301e+01 | lleft: 1.942e-02 | lright: 9.636e-03 | lbottom: 2.534e-04 | lup: 1.249e-02 | linitial: 1.232e-02 | lphy: 1.272e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.942e-02 |  Final lright: 9.636e-03 |  Final lbottom: 2.534e-04 |  Final lup: 1.249e-02 |  Final linitial: 1.232e-02 |  Final lphy: 1.272e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 2300 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 24 | Time: 0.02s | rTime: 4.391e-01h | LR: 1.000e-03 |loss: 1.237e-01 | trace_jacobian_bc: 9.863e+01 | trace_jacobian_ic: 6.318e-01 | trace_jacobian_res: 3.002e+01 | lleft: 6.390e-03 | lright: 6.138e-03 | lbottom: 1.818e-04 | lup: 1.989e-02 | linitial: 1.397e-02 | lphy: 7.712e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 6.390e-03 |  Final lright: 6.138e-03 |  Final lbottom: 1.818e-04 |  Final lup: 1.989e-02 |  Final linitial: 1.397e-02 |  Final lphy: 7.712e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 2400 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 25 | Time: 0.02s | rTime: 4.554e-01h | LR: 1.000e-03 |loss: 1.401e-01 | trace_jacobian_bc: 4.038e+01 | trace_jacobian_ic: 5.744e-01 | trace_jacobian_res: 3.775e+01 | lleft: 1.304e-02 | lright: 9.902e-03 | lbottom: 2.474e-04 | lup: 1.299e-02 | linitial: 2.071e-02 | lphy: 8.323e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.304e-02 |  Final lright: 9.902e-03 |  Final lbottom: 2.474e-04 |  Final lup: 1.299e-02 |  Final linitial: 2.071e-02 |  Final lphy: 8.323e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 2500 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 26 | Time: 0.02s | rTime: 4.751e-01h | LR: 1.000e-03 |loss: 1.178e-01 | trace_jacobian_bc: 2.632e+02 | trace_jacobian_ic: 4.675e-01 | trace_jacobian_res: 1.279e+01 | lleft: 6.150e-03 | lright: 7.374e-03 | lbottom: 2.317e-04 | lup: 3.406e-02 | linitial: 1.457e-02 | lphy: 5.543e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 6.150e-03 |  Final lright: 7.374e-03 |  Final lbottom: 2.317e-04 |  Final lup: 3.406e-02 |  Final linitial: 1.457e-02 |  Final lphy: 5.543e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 2600 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 27 | Time: 0.02s | rTime: 4.917e-01h | LR: 1.000e-03 |loss: 1.279e-01 | trace_jacobian_bc: 2.620e+01 | trace_jacobian_ic: 1.002e+00 | trace_jacobian_res: 1.331e+02 | lleft: 8.195e-03 | lright: 1.236e-02 | lbottom: 2.922e-04 | lup: 7.128e-03 | linitial: 1.573e-02 | lphy: 8.417e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 8.195e-03 |  Final lright: 1.236e-02 |  Final lbottom: 2.922e-04 |  Final lup: 7.128e-03 |  Final linitial: 1.573e-02 |  Final lphy: 8.417e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 2700 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 28 | Time: 0.03s | rTime: 5.180e-01h | LR: 1.000e-03 |loss: 1.082e-01 | trace_jacobian_bc: 8.593e+01 | trace_jacobian_ic: 7.768e-01 | trace_jacobian_res: 1.341e+01 | lleft: 1.467e-02 | lright: 1.994e-03 | lbottom: 2.819e-04 | lup: 1.788e-02 | linitial: 1.381e-02 | lphy: 5.956e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.467e-02 |  Final lright: 1.994e-03 |  Final lbottom: 2.819e-04 |  Final lup: 1.788e-02 |  Final linitial: 1.381e-02 |  Final lphy: 5.956e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 2800 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 29 | Time: 0.02s | rTime: 5.351e-01h | LR: 1.000e-03 |loss: 1.091e-01 | trace_jacobian_bc: 2.702e-01 | trace_jacobian_ic: 8.892e-01 | trace_jacobian_res: 2.038e+01 | lleft: 7.030e-03 | lright: 5.113e-03 | lbottom: 2.276e-04 | lup: 7.248e-03 | linitial: 2.769e-02 | lphy: 6.178e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 7.030e-03 |  Final lright: 5.113e-03 |  Final lbottom: 2.276e-04 |  Final lup: 7.248e-03 |  Final linitial: 2.769e-02 |  Final lphy: 6.178e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 2900 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 30 | Time: 0.02s | rTime: 5.517e-01h | LR: 1.000e-03 |loss: 1.520e-01 | trace_jacobian_bc: 1.883e+02 | trace_jacobian_ic: 1.312e+00 | trace_jacobian_res: 1.626e+01 | lleft: 1.294e-02 | lright: 1.823e-02 | lbottom: 2.180e-04 | lup: 9.665e-03 | linitial: 2.582e-02 | lphy: 8.513e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.294e-02 |  Final lright: 1.823e-02 |  Final lbottom: 2.180e-04 |  Final lup: 9.665e-03 |  Final linitial: 2.582e-02 |  Final lphy: 8.513e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 3000 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 31 | Time: 0.02s | rTime: 5.682e-01h | LR: 1.000e-03 |loss: 1.372e-01 | trace_jacobian_bc: 9.448e-01 | trace_jacobian_ic: 8.429e-01 | trace_jacobian_res: 1.387e+02 | lleft: 1.242e-02 | lright: 5.438e-03 | lbottom: 2.140e-04 | lup: 1.086e-02 | linitial: 1.762e-02 | lphy: 9.062e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.242e-02 |  Final lright: 5.438e-03 |  Final lbottom: 2.140e-04 |  Final lup: 1.086e-02 |  Final linitial: 1.762e-02 |  Final lphy: 9.062e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 3100 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 32 | Time: 0.03s | rTime: 5.938e-01h | LR: 1.000e-03 |loss: 1.030e-01 | trace_jacobian_bc: 6.659e-01 | trace_jacobian_ic: 7.243e-01 | trace_jacobian_res: 2.173e+01 | lleft: 1.137e-02 | lright: 6.667e-03 | lbottom: 4.289e-04 | lup: 1.011e-02 | linitial: 1.131e-02 | lphy: 6.309e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.137e-02 |  Final lright: 6.667e-03 |  Final lbottom: 4.289e-04 |  Final lup: 1.011e-02 |  Final linitial: 1.131e-02 |  Final lphy: 6.309e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 3200 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 33 | Time: 0.02s | rTime: 6.104e-01h | LR: 1.000e-03 |loss: 1.285e-01 | trace_jacobian_bc: 1.166e+01 | trace_jacobian_ic: 7.045e-01 | trace_jacobian_res: 4.234e+01 | lleft: 5.684e-03 | lright: 2.056e-03 | lbottom: 5.553e-04 | lup: 7.163e-03 | linitial: 1.506e-02 | lphy: 9.799e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 5.684e-03 |  Final lright: 2.056e-03 |  Final lbottom: 5.553e-04 |  Final lup: 7.163e-03 |  Final linitial: 1.506e-02 |  Final lphy: 9.799e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 3300 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 34 | Time: 0.02s | rTime: 6.268e-01h | LR: 1.000e-03 |loss: 1.583e-01 | trace_jacobian_bc: 1.284e+00 | trace_jacobian_ic: 7.383e-01 | trace_jacobian_res: 9.079e+01 | lleft: 5.476e-03 | lright: 1.736e-02 | lbottom: 5.860e-04 | lup: 1.171e-02 | linitial: 1.133e-02 | lphy: 1.118e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 5.476e-03 |  Final lright: 1.736e-02 |  Final lbottom: 5.860e-04 |  Final lup: 1.171e-02 |  Final linitial: 1.133e-02 |  Final lphy: 1.118e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 3400 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 35 | Time: 0.02s | rTime: 6.430e-01h | LR: 1.000e-03 |loss: 1.202e-01 | trace_jacobian_bc: 4.164e+00 | trace_jacobian_ic: 3.709e-01 | trace_jacobian_res: 3.535e+01 | lleft: 2.351e-03 | lright: 1.023e-02 | lbottom: 2.182e-04 | lup: 1.017e-02 | linitial: 1.033e-02 | lphy: 8.693e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 2.351e-03 |  Final lright: 1.023e-02 |  Final lbottom: 2.182e-04 |  Final lup: 1.017e-02 |  Final linitial: 1.033e-02 |  Final lphy: 8.693e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 3500 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 36 | Time: 0.02s | rTime: 6.613e-01h | LR: 1.000e-03 |loss: 1.280e-01 | trace_jacobian_bc: 5.824e+01 | trace_jacobian_ic: 1.792e+00 | trace_jacobian_res: 1.253e+01 | lleft: 1.100e-02 | lright: 1.981e-02 | lbottom: 1.265e-03 | lup: 6.654e-03 | linitial: 1.737e-02 | lphy: 7.189e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.100e-02 |  Final lright: 1.981e-02 |  Final lbottom: 1.265e-03 |  Final lup: 6.654e-03 |  Final linitial: 1.737e-02 |  Final lphy: 7.189e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 3600 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 37 | Time: 0.02s | rTime: 6.777e-01h | LR: 1.000e-03 |loss: 1.410e-01 | trace_jacobian_bc: 1.261e+01 | trace_jacobian_ic: 4.553e-01 | trace_jacobian_res: 3.913e+01 | lleft: 4.218e-03 | lright: 1.915e-02 | lbottom: 2.699e-04 | lup: 1.036e-02 | linitial: 1.361e-02 | lphy: 9.341e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 4.218e-03 |  Final lright: 1.915e-02 |  Final lbottom: 2.699e-04 |  Final lup: 1.036e-02 |  Final linitial: 1.361e-02 |  Final lphy: 9.341e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 3700 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 38 | Time: 0.02s | rTime: 6.965e-01h | LR: 1.000e-03 |loss: 1.507e-01 | trace_jacobian_bc: 1.770e+01 | trace_jacobian_ic: 3.988e-01 | trace_jacobian_res: 6.422e+01 | lleft: 1.197e-02 | lright: 8.876e-03 | lbottom: 2.519e-04 | lup: 1.115e-02 | linitial: 1.321e-02 | lphy: 1.053e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.197e-02 |  Final lright: 8.876e-03 |  Final lbottom: 2.519e-04 |  Final lup: 1.115e-02 |  Final linitial: 1.321e-02 |  Final lphy: 1.053e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 3800 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 39 | Time: 0.02s | rTime: 7.126e-01h | LR: 1.000e-03 |loss: 1.095e-01 | trace_jacobian_bc: 3.477e+00 | trace_jacobian_ic: 4.160e-01 | trace_jacobian_res: 9.250e+01 | lleft: 1.042e-02 | lright: 4.550e-03 | lbottom: 1.592e-04 | lup: 1.171e-02 | linitial: 9.575e-03 | lphy: 7.307e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.042e-02 |  Final lright: 4.550e-03 |  Final lbottom: 1.592e-04 |  Final lup: 1.171e-02 |  Final linitial: 9.575e-03 |  Final lphy: 7.307e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 3900 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 40 | Time: 0.02s | rTime: 7.285e-01h | LR: 1.000e-03 |loss: 1.053e-01 | trace_jacobian_bc: 9.150e-01 | trace_jacobian_ic: 1.048e+00 | trace_jacobian_res: 2.651e+01 | lleft: 1.188e-02 | lright: 5.081e-03 | lbottom: 1.328e-04 | lup: 7.859e-03 | linitial: 1.451e-02 | lphy: 6.579e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.188e-02 |  Final lright: 5.081e-03 |  Final lbottom: 1.328e-04 |  Final lup: 7.859e-03 |  Final linitial: 1.451e-02 |  Final lphy: 6.579e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 4000 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 41 | Time: 0.03s | rTime: 7.549e-01h | LR: 1.000e-03 |loss: 1.566e-01 | trace_jacobian_bc: 1.325e+02 | trace_jacobian_ic: 6.244e-01 | trace_jacobian_res: 4.002e+01 | lleft: 5.719e-03 | lright: 4.973e-03 | lbottom: 1.997e-04 | lup: 1.586e-02 | linitial: 1.195e-02 | lphy: 1.179e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 5.719e-03 |  Final lright: 4.973e-03 |  Final lbottom: 1.997e-04 |  Final lup: 1.586e-02 |  Final linitial: 1.195e-02 |  Final lphy: 1.179e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 4100 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 42 | Time: 0.02s | rTime: 7.749e-01h | LR: 1.000e-03 |loss: 1.104e-01 | trace_jacobian_bc: 1.315e+02 | trace_jacobian_ic: 1.121e+00 | trace_jacobian_res: 2.941e+01 | lleft: 4.869e-03 | lright: 2.059e-03 | lbottom: 1.983e-04 | lup: 1.280e-02 | linitial: 1.227e-02 | lphy: 7.817e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 4.869e-03 |  Final lright: 2.059e-03 |  Final lbottom: 1.983e-04 |  Final lup: 1.280e-02 |  Final linitial: 1.227e-02 |  Final lphy: 7.817e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 4200 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 43 | Time: 0.03s | rTime: 8.004e-01h | LR: 1.000e-03 |loss: 9.517e-02 | trace_jacobian_bc: 3.206e+01 | trace_jacobian_ic: 5.413e-01 | trace_jacobian_res: 3.857e+01 | lleft: 4.191e-03 | lright: 4.333e-03 | lbottom: 3.384e-04 | lup: 8.689e-03 | linitial: 1.307e-02 | lphy: 6.454e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 4.191e-03 |  Final lright: 4.333e-03 |  Final lbottom: 3.384e-04 |  Final lup: 8.689e-03 |  Final linitial: 1.307e-02 |  Final lphy: 6.454e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 4300 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 44 | Time: 0.03s | rTime: 8.255e-01h | LR: 1.000e-03 |loss: 1.714e-01 | trace_jacobian_bc: 2.849e+01 | trace_jacobian_ic: 8.187e-01 | trace_jacobian_res: 2.078e+02 | lleft: 3.466e-03 | lright: 4.692e-03 | lbottom: 1.417e-04 | lup: 1.027e-02 | linitial: 9.763e-03 | lphy: 1.431e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 3.466e-03 |  Final lright: 4.692e-03 |  Final lbottom: 1.417e-04 |  Final lup: 1.027e-02 |  Final linitial: 9.763e-03 |  Final lphy: 1.431e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 4400 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 45 | Time: 0.03s | rTime: 8.524e-01h | LR: 1.000e-03 |loss: 1.814e-01 | trace_jacobian_bc: 1.149e+02 | trace_jacobian_ic: 4.623e+00 | trace_jacobian_res: 1.755e+02 | lleft: 3.082e-03 | lright: 1.858e-02 | lbottom: 1.745e-04 | lup: 5.008e-03 | linitial: 2.773e-02 | lphy: 1.268e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 3.082e-03 |  Final lright: 1.858e-02 |  Final lbottom: 1.745e-04 |  Final lup: 5.008e-03 |  Final linitial: 2.773e-02 |  Final lphy: 1.268e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 4500 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 46 | Time: 0.02s | rTime: 8.771e-01h | LR: 1.000e-03 |loss: 1.198e-01 | trace_jacobian_bc: 8.700e-01 | trace_jacobian_ic: 6.328e-01 | trace_jacobian_res: 3.702e+01 | lleft: 8.610e-03 | lright: 3.006e-03 | lbottom: 2.832e-04 | lup: 9.906e-03 | linitial: 1.108e-02 | lphy: 8.688e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 8.610e-03 |  Final lright: 3.006e-03 |  Final lbottom: 2.832e-04 |  Final lup: 9.906e-03 |  Final linitial: 1.108e-02 |  Final lphy: 8.688e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 4600 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 47 | Time: 0.02s | rTime: 8.943e-01h | LR: 1.000e-03 |loss: 1.402e-01 | trace_jacobian_bc: 1.320e+01 | trace_jacobian_ic: 2.357e-01 | trace_jacobian_res: 2.405e+02 | lleft: 4.157e-03 | lright: 9.648e-03 | lbottom: 1.054e-04 | lup: 6.918e-03 | linitial: 7.788e-03 | lphy: 1.116e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 4.157e-03 |  Final lright: 9.648e-03 |  Final lbottom: 1.054e-04 |  Final lup: 6.918e-03 |  Final linitial: 7.788e-03 |  Final lphy: 1.116e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 4700 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 48 | Time: 0.03s | rTime: 9.208e-01h | LR: 1.000e-03 |loss: 1.675e-01 | trace_jacobian_bc: 2.051e+00 | trace_jacobian_ic: 9.038e-01 | trace_jacobian_res: 3.778e+02 | lleft: 6.995e-03 | lright: 1.313e-02 | lbottom: 3.301e-04 | lup: 1.042e-02 | linitial: 1.347e-02 | lphy: 1.231e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 6.995e-03 |  Final lright: 1.313e-02 |  Final lbottom: 3.301e-04 |  Final lup: 1.042e-02 |  Final linitial: 1.347e-02 |  Final lphy: 1.231e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 4800 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 49 | Time: 0.02s | rTime: 9.362e-01h | LR: 1.000e-03 |loss: 1.325e-01 | trace_jacobian_bc: 1.566e+02 | trace_jacobian_ic: 3.028e-01 | trace_jacobian_res: 2.164e+01 | lleft: 4.051e-03 | lright: 6.554e-03 | lbottom: 2.005e-04 | lup: 1.497e-02 | linitial: 9.503e-03 | lphy: 9.727e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 4.051e-03 |  Final lright: 6.554e-03 |  Final lbottom: 2.005e-04 |  Final lup: 1.497e-02 |  Final linitial: 9.503e-03 |  Final lphy: 9.727e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 4900 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 50 | Time: 0.02s | rTime: 9.525e-01h | LR: 1.000e-03 |loss: 1.406e-01 | trace_jacobian_bc: 9.602e+00 | trace_jacobian_ic: 3.586e-01 | trace_jacobian_res: 3.046e+01 | lleft: 9.454e-03 | lright: 1.118e-02 | lbottom: 9.632e-05 | lup: 7.328e-03 | linitial: 1.122e-02 | lphy: 1.013e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 9.454e-03 |  Final lright: 1.118e-02 |  Final lbottom: 9.632e-05 |  Final lup: 7.328e-03 |  Final linitial: 1.122e-02 |  Final lphy: 1.013e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 5000 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 51 | Time: 0.03s | rTime: 9.778e-01h | LR: 1.000e-03 |loss: 2.071e-01 | trace_jacobian_bc: 1.390e+02 | trace_jacobian_ic: 8.782e-01 | trace_jacobian_res: 3.991e+02 | lleft: 2.299e-03 | lright: 6.509e-03 | lbottom: 2.560e-04 | lup: 1.369e-02 | linitial: 7.427e-03 | lphy: 1.770e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 2.299e-03 |  Final lright: 6.509e-03 |  Final lbottom: 2.560e-04 |  Final lup: 1.369e-02 |  Final linitial: 7.427e-03 |  Final lphy: 1.770e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 5100 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 52 | Time: 0.02s | rTime: 9.992e-01h | LR: 1.000e-03 |loss: 1.449e-01 | trace_jacobian_bc: 3.248e+01 | trace_jacobian_ic: 4.184e-01 | trace_jacobian_res: 5.341e+02 | lleft: 9.057e-04 | lright: 5.697e-03 | lbottom: 3.501e-04 | lup: 1.054e-02 | linitial: 8.923e-03 | lphy: 1.185e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 9.057e-04 |  Final lright: 5.697e-03 |  Final lbottom: 3.501e-04 |  Final lup: 1.054e-02 |  Final linitial: 8.923e-03 |  Final lphy: 1.185e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 5200 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 53 | Time: 0.02s | rTime: 1.016e+00h | LR: 1.000e-03 |loss: 1.643e-01 | trace_jacobian_bc: 2.034e+00 | trace_jacobian_ic: 6.881e-01 | trace_jacobian_res: 7.661e+01 | lleft: 8.377e-03 | lright: 2.477e-03 | lbottom: 1.739e-04 | lup: 8.787e-03 | linitial: 8.120e-03 | lphy: 1.364e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 8.377e-03 |  Final lright: 2.477e-03 |  Final lbottom: 1.739e-04 |  Final lup: 8.787e-03 |  Final linitial: 8.120e-03 |  Final lphy: 1.364e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 5300 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 54 | Time: 0.02s | rTime: 1.032e+00h | LR: 1.000e-03 |loss: 1.295e-01 | trace_jacobian_bc: 1.574e+02 | trace_jacobian_ic: 2.261e+00 | trace_jacobian_res: 3.652e+01 | lleft: 1.299e-02 | lright: 5.471e-03 | lbottom: 7.938e-05 | lup: 5.600e-03 | linitial: 2.164e-02 | lphy: 8.370e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.299e-02 |  Final lright: 5.471e-03 |  Final lbottom: 7.938e-05 |  Final lup: 5.600e-03 |  Final linitial: 2.164e-02 |  Final lphy: 8.370e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 5400 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 55 | Time: 0.02s | rTime: 1.049e+00h | LR: 1.000e-03 |loss: 2.475e-01 | trace_jacobian_bc: 1.344e+02 | trace_jacobian_ic: 4.380e-01 | trace_jacobian_res: 1.687e+02 | lleft: 8.285e-03 | lright: 9.687e-03 | lbottom: 1.263e-04 | lup: 5.479e-03 | linitial: 1.694e-02 | lphy: 2.070e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 8.285e-03 |  Final lright: 9.687e-03 |  Final lbottom: 1.263e-04 |  Final lup: 5.479e-03 |  Final linitial: 1.694e-02 |  Final lphy: 2.070e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 5500 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 56 | Time: 0.02s | rTime: 1.068e+00h | LR: 1.000e-03 |loss: 1.480e-01 | trace_jacobian_bc: 9.401e+00 | trace_jacobian_ic: 4.826e-01 | trace_jacobian_res: 5.691e+02 | lleft: 1.487e-02 | lright: 9.602e-03 | lbottom: 3.335e-04 | lup: 8.030e-03 | linitial: 9.854e-03 | lphy: 1.053e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.487e-02 |  Final lright: 9.602e-03 |  Final lbottom: 3.335e-04 |  Final lup: 8.030e-03 |  Final linitial: 9.854e-03 |  Final lphy: 1.053e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 5600 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 57 | Time: 0.02s | rTime: 1.083e+00h | LR: 1.000e-03 |loss: 1.252e-01 | trace_jacobian_bc: 6.040e+01 | trace_jacobian_ic: 2.692e-01 | trace_jacobian_res: 1.289e+03 | lleft: 2.812e-03 | lright: 4.942e-03 | lbottom: 2.418e-04 | lup: 8.333e-03 | linitial: 8.875e-03 | lphy: 1.000e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 2.812e-03 |  Final lright: 4.942e-03 |  Final lbottom: 2.418e-04 |  Final lup: 8.333e-03 |  Final linitial: 8.875e-03 |  Final lphy: 1.000e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 5700 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 58 | Time: 0.02s | rTime: 1.105e+00h | LR: 1.000e-03 |loss: 1.115e-01 | trace_jacobian_bc: 1.922e+00 | trace_jacobian_ic: 3.606e-01 | trace_jacobian_res: 2.214e+02 | lleft: 4.942e-03 | lright: 4.915e-03 | lbottom: 1.403e-04 | lup: 4.604e-03 | linitial: 1.072e-02 | lphy: 8.619e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 4.942e-03 |  Final lright: 4.915e-03 |  Final lbottom: 1.403e-04 |  Final lup: 4.604e-03 |  Final linitial: 1.072e-02 |  Final lphy: 8.619e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 5800 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 59 | Time: 0.02s | rTime: 1.122e+00h | LR: 1.000e-03 |loss: 1.154e-01 | trace_jacobian_bc: 1.226e+01 | trace_jacobian_ic: 1.319e-01 | trace_jacobian_res: 2.010e+02 | lleft: 6.810e-03 | lright: 5.334e-03 | lbottom: 2.136e-04 | lup: 7.500e-03 | linitial: 7.151e-03 | lphy: 8.839e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 6.810e-03 |  Final lright: 5.334e-03 |  Final lbottom: 2.136e-04 |  Final lup: 7.500e-03 |  Final linitial: 7.151e-03 |  Final lphy: 8.839e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 5900 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 60 | Time: 0.02s | rTime: 1.142e+00h | LR: 1.000e-03 |loss: 2.208e-01 | trace_jacobian_bc: 1.764e+01 | trace_jacobian_ic: 5.416e-01 | trace_jacobian_res: 1.264e+03 | lleft: 8.226e-03 | lright: 1.079e-02 | lbottom: 9.056e-05 | lup: 9.368e-03 | linitial: 7.580e-03 | lphy: 1.847e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 8.226e-03 |  Final lright: 1.079e-02 |  Final lbottom: 9.056e-05 |  Final lup: 9.368e-03 |  Final linitial: 7.580e-03 |  Final lphy: 1.847e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 6000 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 61 | Time: 0.02s | rTime: 1.157e+00h | LR: 1.000e-03 |loss: 1.195e-01 | trace_jacobian_bc: 2.783e+00 | trace_jacobian_ic: 3.078e+00 | trace_jacobian_res: 2.623e+02 | lleft: 3.291e-03 | lright: 2.726e-03 | lbottom: 3.120e-04 | lup: 6.945e-03 | linitial: 1.240e-02 | lphy: 9.383e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 3.291e-03 |  Final lright: 2.726e-03 |  Final lbottom: 3.120e-04 |  Final lup: 6.945e-03 |  Final linitial: 1.240e-02 |  Final lphy: 9.383e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 6100 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 62 | Time: 0.02s | rTime: 1.174e+00h | LR: 1.000e-03 |loss: 1.238e-01 | trace_jacobian_bc: 1.581e+00 | trace_jacobian_ic: 2.361e+00 | trace_jacobian_res: 1.765e+02 | lleft: 4.427e-03 | lright: 1.270e-02 | lbottom: 9.901e-05 | lup: 6.056e-03 | linitial: 1.695e-02 | lphy: 8.352e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 4.427e-03 |  Final lright: 1.270e-02 |  Final lbottom: 9.901e-05 |  Final lup: 6.056e-03 |  Final linitial: 1.695e-02 |  Final lphy: 8.352e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 6200 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 63 | Time: 0.02s | rTime: 1.190e+00h | LR: 1.000e-03 |loss: 1.338e-01 | trace_jacobian_bc: 8.286e+01 | trace_jacobian_ic: 7.884e-01 | trace_jacobian_res: 6.614e+01 | lleft: 7.789e-03 | lright: 5.118e-03 | lbottom: 5.687e-04 | lup: 1.370e-02 | linitial: 6.743e-03 | lphy: 9.984e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 7.789e-03 |  Final lright: 5.118e-03 |  Final lbottom: 5.687e-04 |  Final lup: 1.370e-02 |  Final linitial: 6.743e-03 |  Final lphy: 9.984e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 6300 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 64 | Time: 0.03s | rTime: 1.216e+00h | LR: 1.000e-03 |loss: 1.317e-01 | trace_jacobian_bc: 1.370e+01 | trace_jacobian_ic: 1.466e+00 | trace_jacobian_res: 1.612e+02 | lleft: 6.344e-03 | lright: 5.887e-03 | lbottom: 1.004e-04 | lup: 8.278e-03 | linitial: 9.510e-03 | lphy: 1.016e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 6.344e-03 |  Final lright: 5.887e-03 |  Final lbottom: 1.004e-04 |  Final lup: 8.278e-03 |  Final linitial: 9.510e-03 |  Final lphy: 1.016e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 6400 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 65 | Time: 0.02s | rTime: 1.232e+00h | LR: 1.000e-03 |loss: 9.577e-02 | trace_jacobian_bc: 1.137e+01 | trace_jacobian_ic: 3.118e-01 | trace_jacobian_res: 6.447e+01 | lleft: 1.054e-02 | lright: 4.118e-03 | lbottom: 1.139e-04 | lup: 1.103e-02 | linitial: 7.531e-03 | lphy: 6.243e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.054e-02 |  Final lright: 4.118e-03 |  Final lbottom: 1.139e-04 |  Final lup: 1.103e-02 |  Final linitial: 7.531e-03 |  Final lphy: 6.243e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 6500 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 66 | Time: 0.02s | rTime: 1.248e+00h | LR: 1.000e-03 |loss: 9.544e-02 | trace_jacobian_bc: 2.280e+00 | trace_jacobian_ic: 8.367e-02 | trace_jacobian_res: 1.745e+01 | lleft: 4.743e-04 | lright: 9.451e-03 | lbottom: 5.907e-05 | lup: 3.212e-03 | linitial: 3.918e-03 | lphy: 7.833e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 4.743e-04 |  Final lright: 9.451e-03 |  Final lbottom: 5.907e-05 |  Final lup: 3.212e-03 |  Final linitial: 3.918e-03 |  Final lphy: 7.833e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 6600 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 67 | Time: 0.02s | rTime: 1.266e+00h | LR: 1.000e-03 |loss: 2.732e-01 | trace_jacobian_bc: 9.737e-01 | trace_jacobian_ic: 3.487e+00 | trace_jacobian_res: 1.683e+02 | lleft: 4.737e-03 | lright: 5.630e-04 | lbottom: 3.962e-04 | lup: 4.856e-03 | linitial: 1.236e-02 | lphy: 2.503e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 4.737e-03 |  Final lright: 5.630e-04 |  Final lbottom: 3.962e-04 |  Final lup: 4.856e-03 |  Final linitial: 1.236e-02 |  Final lphy: 2.503e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 6700 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 68 | Time: 0.02s | rTime: 1.282e+00h | LR: 1.000e-03 |loss: 1.625e-01 | trace_jacobian_bc: 1.648e+02 | trace_jacobian_ic: 3.288e+00 | trace_jacobian_res: 7.513e+02 | lleft: 9.590e-03 | lright: 1.307e-02 | lbottom: 1.781e-04 | lup: 3.864e-03 | linitial: 9.672e-03 | lphy: 1.262e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 9.590e-03 |  Final lright: 1.307e-02 |  Final lbottom: 1.781e-04 |  Final lup: 3.864e-03 |  Final linitial: 9.672e-03 |  Final lphy: 1.262e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 6800 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 69 | Time: 0.02s | rTime: 1.298e+00h | LR: 1.000e-03 |loss: 7.296e-02 | trace_jacobian_bc: 1.237e+02 | trace_jacobian_ic: 6.282e-01 | trace_jacobian_res: 9.690e+00 | lleft: 1.992e-03 | lright: 3.226e-03 | lbottom: 4.223e-04 | lup: 1.067e-02 | linitial: 6.913e-03 | lphy: 4.973e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.992e-03 |  Final lright: 3.226e-03 |  Final lbottom: 4.223e-04 |  Final lup: 1.067e-02 |  Final linitial: 6.913e-03 |  Final lphy: 4.973e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 6900 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 70 | Time: 0.02s | rTime: 1.315e+00h | LR: 1.000e-03 |loss: 1.348e-01 | trace_jacobian_bc: 1.712e+00 | trace_jacobian_ic: 2.277e+00 | trace_jacobian_res: 3.852e+02 | lleft: 3.674e-03 | lright: 7.431e-03 | lbottom: 1.308e-04 | lup: 7.736e-03 | linitial: 1.205e-02 | lphy: 1.038e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 3.674e-03 |  Final lright: 7.431e-03 |  Final lbottom: 1.308e-04 |  Final lup: 7.736e-03 |  Final linitial: 1.205e-02 |  Final lphy: 1.038e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 7000 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# ...
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 57800 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 579 | Time: 0.02s | rTime: 1.180e+01h | LR: 1.000e-03 |loss: 1.196e-01 | trace_jacobian_bc: 1.478e+01 | trace_jacobian_ic: 8.067e+00 | trace_jacobian_res: 8.457e+01 | lleft: 1.974e-03 | lright: 1.030e-03 | lbottom: 1.392e-05 | lup: 5.333e-03 | linitial: 7.591e-03 | lphy: 1.037e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.974e-03 |  Final lright: 1.030e-03 |  Final lbottom: 1.392e-05 |  Final lup: 5.333e-03 |  Final linitial: 7.591e-03 |  Final lphy: 1.037e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 57900 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 580 | Time: 0.02s | rTime: 1.182e+01h | LR: 1.000e-03 |loss: 9.830e-02 | trace_jacobian_bc: 7.529e+01 | trace_jacobian_ic: 1.685e-01 | trace_jacobian_res: 4.716e+01 | lleft: 1.060e-03 | lright: 1.250e-03 | lbottom: 1.164e-04 | lup: 7.965e-03 | linitial: 3.351e-03 | lphy: 8.455e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.060e-03 |  Final lright: 1.250e-03 |  Final lbottom: 1.164e-04 |  Final lup: 7.965e-03 |  Final linitial: 3.351e-03 |  Final lphy: 8.455e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 58000 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 581 | Time: 0.02s | rTime: 1.183e+01h | LR: 1.000e-03 |loss: 8.470e-02 | trace_jacobian_bc: 1.358e+02 | trace_jacobian_ic: 1.822e-01 | trace_jacobian_res: 3.727e+01 | lleft: 5.899e-04 | lright: 2.137e-04 | lbottom: 4.993e-05 | lup: 7.481e-03 | linitial: 3.633e-03 | lphy: 7.273e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 5.899e-04 |  Final lright: 2.137e-04 |  Final lbottom: 4.993e-05 |  Final lup: 7.481e-03 |  Final linitial: 3.633e-03 |  Final lphy: 7.273e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 58100 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 582 | Time: 0.02s | rTime: 1.185e+01h | LR: 1.000e-03 |loss: 8.246e-02 | trace_jacobian_bc: 1.715e+01 | trace_jacobian_ic: 2.299e-01 | trace_jacobian_res: 2.571e+02 | lleft: 4.141e-03 | lright: 2.146e-03 | lbottom: 4.954e-05 | lup: 3.862e-03 | linitial: 3.229e-03 | lphy: 6.904e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 4.141e-03 |  Final lright: 2.146e-03 |  Final lbottom: 4.954e-05 |  Final lup: 3.862e-03 |  Final linitial: 3.229e-03 |  Final lphy: 6.904e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 58200 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 583 | Time: 0.02s | rTime: 1.187e+01h | LR: 1.000e-03 |loss: 2.827e-01 | trace_jacobian_bc: 1.466e+02 | trace_jacobian_ic: 3.506e+00 | trace_jacobian_res: 1.083e+03 | lleft: 3.854e-03 | lright: 4.833e-03 | lbottom: 5.358e-05 | lup: 5.199e-03 | linitial: 4.265e-03 | lphy: 2.645e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 3.854e-03 |  Final lright: 4.833e-03 |  Final lbottom: 5.358e-05 |  Final lup: 5.199e-03 |  Final linitial: 4.265e-03 |  Final lphy: 2.645e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 58300 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 584 | Time: 0.02s | rTime: 1.188e+01h | LR: 1.000e-03 |loss: 4.945e-02 | trace_jacobian_bc: 1.341e+01 | trace_jacobian_ic: 6.782e-01 | trace_jacobian_res: 3.363e+01 | lleft: 4.896e-03 | lright: 1.328e-03 | lbottom: 9.736e-05 | lup: 5.665e-03 | linitial: 5.205e-03 | lphy: 3.226e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 4.896e-03 |  Final lright: 1.328e-03 |  Final lbottom: 9.736e-05 |  Final lup: 5.665e-03 |  Final linitial: 5.205e-03 |  Final lphy: 3.226e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 58400 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 585 | Time: 0.02s | rTime: 1.190e+01h | LR: 1.000e-03 |loss: 1.131e-01 | trace_jacobian_bc: 3.368e+00 | trace_jacobian_ic: 2.975e+01 | trace_jacobian_res: 2.300e+01 | lleft: 1.869e-03 | lright: 5.904e-04 | lbottom: 4.941e-05 | lup: 2.282e-03 | linitial: 1.373e-02 | lphy: 9.459e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.869e-03 |  Final lright: 5.904e-04 |  Final lbottom: 4.941e-05 |  Final lup: 2.282e-03 |  Final linitial: 1.373e-02 |  Final lphy: 9.459e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 58500 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 586 | Time: 0.02s | rTime: 1.192e+01h | LR: 1.000e-03 |loss: 8.386e-02 | trace_jacobian_bc: 1.198e+02 | trace_jacobian_ic: 5.920e-01 | trace_jacobian_res: 3.386e+01 | lleft: 1.571e-03 | lright: 1.570e-03 | lbottom: 7.171e-05 | lup: 1.341e-02 | linitial: 5.111e-03 | lphy: 6.213e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.571e-03 |  Final lright: 1.570e-03 |  Final lbottom: 7.171e-05 |  Final lup: 1.341e-02 |  Final linitial: 5.111e-03 |  Final lphy: 6.213e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 58600 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 587 | Time: 0.02s | rTime: 1.194e+01h | LR: 1.000e-03 |loss: 1.102e-01 | trace_jacobian_bc: 1.672e+02 | trace_jacobian_ic: 1.509e-01 | trace_jacobian_res: 2.031e+01 | lleft: 1.638e-03 | lright: 1.155e-03 | lbottom: 4.088e-05 | lup: 1.821e-02 | linitial: 2.736e-03 | lphy: 8.645e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.638e-03 |  Final lright: 1.155e-03 |  Final lbottom: 4.088e-05 |  Final lup: 1.821e-02 |  Final linitial: 2.736e-03 |  Final lphy: 8.645e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 58700 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 588 | Time: 0.02s | rTime: 1.196e+01h | LR: 1.000e-03 |loss: 6.174e-02 | trace_jacobian_bc: 1.487e+00 | trace_jacobian_ic: 8.319e-02 | trace_jacobian_res: 1.920e+01 | lleft: 2.253e-03 | lright: 4.096e-03 | lbottom: 1.829e-04 | lup: 2.570e-03 | linitial: 1.406e-03 | lphy: 5.123e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 2.253e-03 |  Final lright: 4.096e-03 |  Final lbottom: 1.829e-04 |  Final lup: 2.570e-03 |  Final linitial: 1.406e-03 |  Final lphy: 5.123e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 58800 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 589 | Time: 0.02s | rTime: 1.198e+01h | LR: 1.000e-03 |loss: 2.716e-01 | trace_jacobian_bc: 6.197e+01 | trace_jacobian_ic: 1.389e+01 | trace_jacobian_res: 8.834e+02 | lleft: 3.422e-04 | lright: 6.438e-03 | lbottom: 4.780e-05 | lup: 9.191e-03 | linitial: 9.772e-03 | lphy: 2.458e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 3.422e-04 |  Final lright: 6.438e-03 |  Final lbottom: 4.780e-05 |  Final lup: 9.191e-03 |  Final linitial: 9.772e-03 |  Final lphy: 2.458e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 58900 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 590 | Time: 0.02s | rTime: 1.200e+01h | LR: 1.000e-03 |loss: 4.313e-01 | trace_jacobian_bc: 1.966e+00 | trace_jacobian_ic: 2.356e+00 | trace_jacobian_res: 1.296e+03 | lleft: 5.667e-03 | lright: 3.421e-03 | lbottom: 6.728e-05 | lup: 2.793e-03 | linitial: 4.655e-03 | lphy: 4.147e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 5.667e-03 |  Final lright: 3.421e-03 |  Final lbottom: 6.728e-05 |  Final lup: 2.793e-03 |  Final linitial: 4.655e-03 |  Final lphy: 4.147e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 59000 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 591 | Time: 0.02s | rTime: 1.202e+01h | LR: 1.000e-03 |loss: 9.774e-02 | trace_jacobian_bc: 3.890e+01 | trace_jacobian_ic: 4.343e-01 | trace_jacobian_res: 3.117e+02 | lleft: 8.163e-03 | lright: 5.622e-03 | lbottom: 1.443e-04 | lup: 3.681e-03 | linitial: 7.091e-03 | lphy: 7.304e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 8.163e-03 |  Final lright: 5.622e-03 |  Final lbottom: 1.443e-04 |  Final lup: 3.681e-03 |  Final linitial: 7.091e-03 |  Final lphy: 7.304e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 59100 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 592 | Time: 0.02s | rTime: 1.204e+01h | LR: 1.000e-03 |loss: 1.187e-01 | trace_jacobian_bc: 2.579e+02 | trace_jacobian_ic: 4.002e-01 | trace_jacobian_res: 2.534e+01 | lleft: 3.827e-03 | lright: 3.736e-04 | lbottom: 2.225e-04 | lup: 2.539e-02 | linitial: 4.126e-03 | lphy: 8.476e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 3.827e-03 |  Final lright: 3.736e-04 |  Final lbottom: 2.225e-04 |  Final lup: 2.539e-02 |  Final linitial: 4.126e-03 |  Final lphy: 8.476e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 59200 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 593 | Time: 0.01s | rTime: 1.205e+01h | LR: 1.000e-03 |loss: 1.385e-01 | trace_jacobian_bc: 8.972e+00 | trace_jacobian_ic: 5.652e-01 | trace_jacobian_res: 3.676e+02 | lleft: 3.949e-03 | lright: 8.026e-03 | lbottom: 4.443e-05 | lup: 3.451e-03 | linitial: 3.550e-03 | lphy: 1.195e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 3.949e-03 |  Final lright: 8.026e-03 |  Final lbottom: 4.443e-05 |  Final lup: 3.451e-03 |  Final linitial: 3.550e-03 |  Final lphy: 1.195e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 59300 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 594 | Time: 0.02s | rTime: 1.207e+01h | LR: 1.000e-03 |loss: 1.079e-01 | trace_jacobian_bc: 1.564e+01 | trace_jacobian_ic: 2.096e-01 | trace_jacobian_res: 4.144e+01 | lleft: 1.485e-03 | lright: 3.946e-03 | lbottom: 2.761e-05 | lup: 6.403e-03 | linitial: 2.916e-03 | lphy: 9.308e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.485e-03 |  Final lright: 3.946e-03 |  Final lbottom: 2.761e-05 |  Final lup: 6.403e-03 |  Final linitial: 2.916e-03 |  Final lphy: 9.308e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 59400 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 595 | Time: 0.02s | rTime: 1.208e+01h | LR: 1.000e-03 |loss: 1.512e-01 | trace_jacobian_bc: 2.027e+01 | trace_jacobian_ic: 3.499e+00 | trace_jacobian_res: 4.374e+02 | lleft: 3.164e-04 | lright: 8.187e-03 | lbottom: 4.682e-05 | lup: 5.450e-03 | linitial: 5.346e-03 | lphy: 1.318e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 3.164e-04 |  Final lright: 8.187e-03 |  Final lbottom: 4.682e-05 |  Final lup: 5.450e-03 |  Final linitial: 5.346e-03 |  Final lphy: 1.318e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 59500 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 596 | Time: 0.02s | rTime: 1.210e+01h | LR: 1.000e-03 |loss: 4.216e-01 | trace_jacobian_bc: 1.336e+02 | trace_jacobian_ic: 8.047e+00 | trace_jacobian_res: 1.306e+03 | lleft: 3.154e-03 | lright: 1.004e-02 | lbottom: 7.040e-05 | lup: 4.278e-03 | linitial: 7.386e-03 | lphy: 3.967e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 3.154e-03 |  Final lright: 1.004e-02 |  Final lbottom: 7.040e-05 |  Final lup: 4.278e-03 |  Final linitial: 7.386e-03 |  Final lphy: 3.967e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 59600 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 597 | Time: 0.01s | rTime: 1.211e+01h | LR: 1.000e-03 |loss: 8.051e-02 | trace_jacobian_bc: 1.701e+01 | trace_jacobian_ic: 9.884e+00 | trace_jacobian_res: 1.221e+02 | lleft: 2.313e-03 | lright: 3.006e-03 | lbottom: 3.860e-05 | lup: 4.576e-03 | linitial: 6.776e-03 | lphy: 6.380e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 2.313e-03 |  Final lright: 3.006e-03 |  Final lbottom: 3.860e-05 |  Final lup: 4.576e-03 |  Final linitial: 6.776e-03 |  Final lphy: 6.380e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 59700 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 598 | Time: 0.02s | rTime: 1.213e+01h | LR: 1.000e-03 |loss: 5.439e-02 | trace_jacobian_bc: 3.824e+00 | trace_jacobian_ic: 1.135e-01 | trace_jacobian_res: 1.061e+01 | lleft: 1.531e-03 | lright: 4.473e-03 | lbottom: 3.531e-05 | lup: 4.193e-03 | linitial: 4.403e-03 | lphy: 3.976e-02 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 1.531e-03 |  Final lright: 4.473e-03 |  Final lbottom: 3.531e-05 |  Final lup: 4.193e-03 |  Final linitial: 4.403e-03 |  Final lphy: 3.976e-02 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 59800 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 599 | Time: 0.02s | rTime: 1.214e+01h | LR: 1.000e-03 |loss: 1.536e-01 | trace_jacobian_bc: 5.153e+01 | trace_jacobian_ic: 1.528e+00 | trace_jacobian_res: 1.499e+02 | lleft: 3.149e-04 | lright: 1.825e-02 | lbottom: 1.171e-04 | lup: 2.060e-03 | linitial: 6.145e-03 | lphy: 1.267e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 3.149e-04 |  Final lright: 1.825e-02 |  Final lbottom: 1.171e-04 |  Final lup: 2.060e-03 |  Final linitial: 6.145e-03 |  Final lphy: 1.267e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 59900 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger: Epoch: 600 | Time: 0.02s | rTime: 1.216e+01h | LR: 1.000e-03 |loss: 2.090e-01 | trace_jacobian_bc: 5.623e+01 | trace_jacobian_ic: 2.410e-01 | trace_jacobian_res: 9.402e+02 | lleft: 2.280e-03 | lright: 7.793e-04 | lbottom: 1.733e-04 | lup: 6.358e-03 | linitial: 4.271e-03 | lphy: 1.952e-01 |
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 2.280e-03 |  Final lright: 7.793e-04 |  Final lbottom: 1.733e-04 |  Final lup: 6.358e-03 |  Final linitial: 4.271e-03 |  Final lphy: 1.952e-01 |
# INFO:src.utils.logger:_summary of the model _
# INFO:src.utils.logger:model configuration:
# INFO:src.utils.logger:problem : cavity
# INFO:src.utils.logger:dataset_path : ./data/cavity.mat
# INFO:src.utils.logger:batch_size : 128
# INFO:src.utils.logger:total_epochs : 60000
# INFO:src.utils.logger:activation : tanh
# INFO:src.utils.logger:network : [3, 50, 50, 50, 3]
# INFO:src.utils.logger:weights : [2.0, 2.0, 2.0, 2.0, 2.0, 0.1]
# INFO:src.utils.logger:log_path : ./checkpoint
# INFO:src.utils.logger:loss_list : ['lleft', 'lright', 'lbottom', 'lup', 'linitial', 'lphy']
# INFO:src.utils.logger:solver : tanh
# INFO:src.utils.logger:print_every : 100
# INFO:src.utils.logger:save_every : 100
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 60000 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final lleft: 2.280e-03 |  Final lright: 7.793e-04 |  Final lbottom: 1.733e-04 |  Final lup: 6.358e-03 |  Final linitial: 4.271e-03 |  Final lphy: 1.952e-01 |
# INFO:src.utils.logger:_save_checkpoint: [GPU:0] Epoch 60001 | Training checkpoint saved at ./checkpoint/2025-05-24_10-29-34-158138/model.pth

# %%
model_path = os.path.join(trainer.logger.get_output_dir(), "model.pth")

max_eig_hessian_bc_log_dic = {}
max_eig_hessian_res_log_dic = {}
max_eig_hessian_ic_log_dic = {}

trace_jacobian_bc_log_dic = {}
trace_jacobian_res_log_dic = {}
trace_jacobian_ic_log_dic = {}

state = torch.load(model_path)
config = state.get("config", {})
solver = config.get("solver")
trace_jacobian_bc_log = state.get("trace_jacobian_bc_log")
trace_jacobian_ic_log = state.get("trace_jacobian_ic_log")
trace_jacobian_res_log = state.get("trace_jacobian_res_log")

model_activation_name = config.get("activation")
model_architecture = config.get("network")
loss_dict = state.get("loss_history")

max_eig_hessian_bc_log_dic[model_activation_name] = max_eig_hessian_bc_log
max_eig_hessian_res_log_dic[model_activation_name] = max_eig_hessian_res_log
max_eig_hessian_ic_log_dic[model_activation_name] = max_eig_hessian_ic_log

trace_jacobian_bc_log_dic[model_activation_name] = trace_jacobian_bc_log
trace_jacobian_res_log_dic[model_activation_name] = trace_jacobian_res_log
trace_jacobian_ic_log_dic[model_activation_name] = trace_jacobian_ic_log
# Out:
# /tmp/ipykernel_3393/2994138775.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(model_path)

# %%
fig, ax = plt.subplots(1, 3)
fig.set_size_inches([16, 3.5])  # Adjusted figure size
dict_list = [
    trace_jacobian_bc_log_dic,
    trace_jacobian_ic_log_dic,
    trace_jacobian_res_log_dic,
]
lines = []  # List to collect Line2D objects for the legend
labels = []  # List to collect corresponding labels

for index in range(len(dict_list)):
    data_list = [
        {
            "data": dict_list[index]["tanh"],
            "color": model_color["tanh"],
            "name": "Tanh",
            "alpha": 1.0,
        },
    ]

    plot_spectral(ax[index], data_list)

for line in ax[-1].get_lines():
    lines.append(line)
    labels.append(line.get_label())

save_path = os.path.join(logger.get_output_dir(), "spectral_cavity.png")

legend = fig.legend(
    lines, labels, loc="upper center", bbox_to_anchor=(0.5, 1.1), ncol=7
)
legend.get_frame().set_facecolor("white")

plt.tight_layout()
plt.savefig(save_path)

# %%
fig, ax = plt.subplots(1, 3)
fig.set_size_inches([16, 3.5])  # Adjusted figure size
dict_list = [
    max_eig_hessian_bc_log_dic,
    max_eig_hessian_ic_log_dic,
    max_eig_hessian_res_log_dic,
]
lines = []  # List to collect Line2D objects for the legend
labels = []  # List to collect corresponding labels

for index in range(len(dict_list)):
    data_list = [
        # {
        #     "data": dict_list[index]["bspline"],
        #     "color": model_color["bspline"],
        #     "name": "B-spline",
        #     "alpha": 1.0,
        # },
        {
            "data": dict_list[index]["tanh"],
            "color": model_color["tanh"],
            "name": "Tanh",
            "alpha": 1.0,
        },
        # {
        #     "data": dict_list[index]["grbf"],
        #     "color": model_color["grbf"],
        #     "name": "GRBF",
        #     "alpha": 1.0,
        # },
        # {
        #     "data": dict_list[index]["fourier"],
        #     "color": model_color["fourier"],
        #     "name": "Fourier",
        #     "alpha": 1.0,
        # },
        # {
        #     "data": dict_list[index]["param_tanh"],
        #     "color": model_color["param_tanh"],
        #     "name": "parametric-Tanh",
        #     "alpha": 1.0,
        # },
        # {
        #     "data": dict_list[index]["chebyshev"],
        #     "color": model_color["chebyshev"],
        #     "name": "Chebyshev",
        #     "alpha": 1.0,
        # },
        # {
        #     "data": dict_list[index]["jacobi"],
        #     "color": model_color["jacobi"],
        #     "name": "Jacobi",
        #     "alpha": 1.0,
        # },
    ]

    plot_spectral(ax[index], data_list)

for line in ax[-1].get_lines():
    lines.append(line)
    labels.append(line.get_label())

save_path = os.path.join(logger.get_output_dir(), "spectral_cavity.png")

legend = fig.legend(
    lines, labels, loc="upper center", bbox_to_anchor=(0.5, 1.1), ncol=7
)
legend.get_frame().set_facecolor("white")

plt.tight_layout()
plt.savefig(save_path)
