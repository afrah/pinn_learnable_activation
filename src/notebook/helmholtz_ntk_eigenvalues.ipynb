# %% [markdown]
# # Convergence Behavior Analysis of Helmholtz

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import torch
import gc
import numpy as np
from matplotlib import pyplot as plt
import os

# %% [markdown]
# Import local packages

# %%
from src.utils.logger import Logging
from src.utils.color import model_color
from src.utils.plot_eigenvalues import plot_ntk_eigenvalues

# %% [markdown]
# Set various constant variables: model path, name, etc. We choose the best performing models from each architecture.

# %%
TEST_CHECKPOINT_PATH = os.path.join("result/helmholtz")
logger = Logging(TEST_CHECKPOINT_PATH)
result_dir = logger.get_output_dir()
print(f"{result_dir=}")
# Out:
# result_dir='result/helmholtz/2025-05-29_17-28-42-866163'

# %%
# # tanh
# python -m src.trainer.main_trainer --total_epochs 60000  --save_every 1000 --print_every 1000 --batch_size 128 --log_path ./checkpoints --solver tanh --
# problem helmholtz --weights "[10.0, 1.0]" --network "[2, 30, 30, 30, 1]"

# # param_tanh
# python -m src.trainer.main_trainer --total_epochs 60000  --save_every 1000 --print_every 1000 --batch_size 128 --log_path ./checkpoints --solver param_tanh --
# problem helmholtz --weights "[10.0, 1.0]" --network "[2, 30, 30, 30, 1]"

# # bspline
# python -m src.trainer.main_trainer --total_epochs 60000  --save_every 1000 --print_every 1000 --batch_size 128 --log_path ./checkpoints --solver bspline --
# problem helmholtz --weights "[10.0, 1.0]" --network "[2, 30, 30, 30, 1]"

# # grbf
# python -m src.trainer.main_trainer --total_epochs 60000  --save_every 1000 --print_every 1000 --batch_size 128 --log_path ./checkpoints --solver grbf --
# problem helmholtz --weights "[10.0, 1.0]" --network "[2, 30, 30, 30, 1]"

# # fourier
# python -m src.trainer.main_trainer --total_epochs 60000  --save_every 1000 --print_every 1000 --batch_size 128 --log_path ./checkpoints --solver fourier --
# problem helmholtz --weights "[10.0, 1.0]" --network "[2, 30, 30, 30, 1]"

# # chebyshev
# python -m src.trainer.main_trainer --total_epochs 60000  --save_every 1000 --print_every 1000 --batch_size 128 --log_path ./checkpoints --solver chebyshev --
# problem helmholtz --weights "[10.0, 1.0]" --network "[2, 30, 30, 30, 1]"

# # jacobi
# python -m src.trainer.main_trainer --total_epochs 60000  --save_every 1000 --print_every 1000 --batch_size 128 --log_path ./checkpoints --solver jacobi --
# problem helmholtz --weights "[10.0, 1.0]" --network "[2, 30, 30, 30, 1]"

# %%
TANH_NORM_DIST = ""
TANH_PARAM_DIST = ""
BSPLINE_DIST = ""
GRBF_DIST = ""
FOURIER_DIST = ""
CHEBTSHEV_DIST = ""
JACOBI_DIST = ""


MODEL_PATH_LIST = {
    "tanh": TANH_NORM_DIST,
    "param_tanh": TANH_PARAM_DIST,
    "grbf": GRBF_DIST,
    "bspline": BSPLINE_DIST,
    "chebyshev": CHEBTSHEV_DIST,
    "jacobi": JACOBI_DIST,
    "fourier": FOURIER_DIST,
}

# %% [markdown]
# ## Load the saved models, Test and Print Prediction Accuracy

# %%
trace_jacobian_bc_log_dic = {}
trace_jacobian_res_log_dic = {}

for model_name, model_path in MODEL_PATH_LIST.items():
    logger.print(f"MODEL_PATH {model_path}")

    state = torch.load(
        model_path,
    )
    config = state.get("config", {})
    solver = config.get("solver")
    trace_jacobian_bc_log = state.get("trace_jacobian_bc_log")
    trace_jacobian_res_log = state.get("trace_jacobian_res_log")
    model_activation_name = config.get("activation")
    model_architecture = config.get("network")
    loss_dict = state.get("loss_history")

    logger.print(f"activation:  , {model_activation_name}")
    logger.print(f"problem: {config.get('problem')}")
    logger.print(f"solver:  , {solver}")
    logger.print(f"network:  , {config.get('network')}")
    logger.print(f"term loss weights :  , {config.get('weights')}")

    # logger.print(
    #     f"Model {model_name} with iterations: {len(loss_dict[next(iter(loss_dict))])}"
    # )

    trace_jacobian_bc_log_dic[model_name] = trace_jacobian_bc_log
    trace_jacobian_res_log_dic[model_name] = trace_jacobian_res_log

    logger.print("******************************\n")
    gc.collect()
    torch.cuda.empty_cache()

logger.print("file directory:", logger.get_output_dir())
# Out:
# INFO:src.utils.logger:MODEL_PATH ./checkpoints/2025-05-29_17-21-46-237585/model.pth
# INFO:src.utils.logger:activation:  , None
# INFO:src.utils.logger:problem: helmholtz
# INFO:src.utils.logger:solver:  , tanh
# INFO:src.utils.logger:network:  , [2, 30, 30, 30, 1]
# INFO:src.utils.logger:term loss weights :  , [10.0, 1.0]
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:MODEL_PATH ./checkpoints/2025-05-29_17-23-41-951343/model.pth
# INFO:src.utils.logger:activation:  , None
# INFO:src.utils.logger:problem: helmholtz
# INFO:src.utils.logger:solver:  , param_tanh
# INFO:src.utils.logger:network:  , [2, 30, 30, 30, 1]
# INFO:src.utils.logger:term loss weights :  , [10.0, 1.0]
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:MODEL_PATH ./checkpoints/2025-05-29_17-26-11-554670/model.pth
# INFO:src.utils.logger:activation:  , None
# INFO:src.utils.logger:problem: helmholtz
# INFO:src.utils.logger:solver:  , grbf
# INFO:src.utils.logger:network:  , [2, 30, 30, 30, 1]
# INFO:src.utils.logger:term loss weights :  , [10.0, 1.0]
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:MODEL_PATH ./checkpoints/2025-05-29_17-20-36-731890/model.pth
# INFO:src.utils.logger:activation:  , None
# INFO:src.utils.logger:problem: helmholtz
# INFO:src.utils.logger:solver:  , bspline
# INFO:src.utils.logger:network:  , [2, 30, 30, 30, 1]
# INFO:src.utils.logger:term loss weights :  , [10.0, 1.0]
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:MODEL_PATH ./checkpoints/2025-05-29_17-25-18-328716/model.pth
# INFO:src.utils.logger:activation:  , None
# INFO:src.utils.logger:problem: helmholtz
# INFO:src.utils.logger:solver:  , chebyshev
# INFO:src.utils.logger:network:  , [2, 30, 30, 30, 1]
# INFO:src.utils.logger:term loss weights :  , [10.0, 1.0]
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:MODEL_PATH ./checkpoints/2025-05-29_17-28-18-091789/model.pth
# INFO:src.utils.logger:activation:  , None
# INFO:src.utils.logger:problem: helmholtz
# INFO:src.utils.logger:solver:  , jacobi
# INFO:src.utils.logger:network:  , [2, 30, 30, 30, 1]
# INFO:src.utils.logger:term loss weights :  , [10.0, 1.0]
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:MODEL_PATH ./checkpoints/2025-05-29_17-27-30-479894/model.pth
# INFO:src.utils.logger:activation:  , None
# INFO:src.utils.logger:problem: helmholtz
# INFO:src.utils.logger:solver:  , fourier
# INFO:src.utils.logger:network:  , [2, 30, 30, 30, 1]
# INFO:src.utils.logger:term loss weights :  , [10.0, 1.0]
# INFO:src.utils.logger:******************************
#
# INFO:src.utils.logger:file directory:
# INFO:src.utils.logger:result/helmholtz/2025-05-29_17-28-42-866163

# %%
min_length = min(len(trace_jacobian_bc_log_dic[k]) for k in trace_jacobian_bc_log_dic)
time_iterations = [0, min_length // 2, min_length - 1]

dict_list = [
    trace_jacobian_bc_log_dic,
    trace_jacobian_res_log_dic,
]

rows = len(time_iterations)
cols = len(dict_list)

fig, ax = plt.subplots(rows, cols)
fig.set_size_inches([10, 5.5])

lines = []
labels = []

for row, time_iteration in enumerate(time_iterations):
    for col, dict_ in enumerate(dict_list):
        data_list = [
            {
                "data": dict_["bspline"][time_iteration],
                "color": model_color["bspline"],
                "name": "B-spline(A1)",
                "alpha": 1.0,
            },
            {
                "data": dict_["tanh"][time_iteration],
                "color": model_color["tanh"],
                "name": "Tanh(A2)",
                "alpha": 1.0,
            },
            {
                "data": dict_["grbf"][time_iteration],
                "color": model_color["grbf"],
                "name": "GRBF(A2)",
                "alpha": 1.0,
            },
            {
                "data": dict_["fourier"][time_iteration],
                "color": model_color["fourier"],
                "name": "Fourier(A1)",
                "alpha": 1.0,
            },
            {
                "data": dict_["param_tanh"][time_iteration],
                "color": model_color["param_tanh"],
                "name": "parametric-Tanh(A2)",
                "alpha": 1.0,
            },
            {
                "data": dict_["chebyshev"][time_iteration],
                "color": model_color["chebyshev"],
                "name": "Chebyshev(A1)",
                "alpha": 1.0,
            },
            {
                "data": dict_["jacobi"][time_iteration],
                "color": model_color["jacobi"],
                "name": "Jacobi(A1)",
                "alpha": 1.0,
            },
        ]

        plot_ntk_eigenvalues(ax[row, col], data_list, row, col, smoothed_data=False)

for line in ax[-1, -1].get_lines():
    lines.append(line)
    labels.append(line.get_label())

save_path = os.path.join(logger.get_output_dir(), "trace_jacobian_wave.png")

legend = fig.legend(
    lines, labels, loc="upper center", bbox_to_anchor=(0.5, 1.05), ncol=7
)
legend.get_frame().set_facecolor("white")

plt.tight_layout()
plt.savefig(save_path)
